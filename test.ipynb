# %% [markdown]
# # TEST

# %%
print("Hello Valentin! Hello Kristian")
# Out:
# Hello Valentin! Hello Kristian

# %% [markdown]
# You may add some lines, then use the last cell in the "Colab-GDrive-GitHub.ipynb" to upload your changes including a commit message, where you describe, what you did!
